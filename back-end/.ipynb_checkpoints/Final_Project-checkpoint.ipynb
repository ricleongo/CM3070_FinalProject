# %%
import pandas as pd
import numpy as np

import tensorflow as tf
import networkx as nx

from sklearn.metrics import f1_score, roc_auc_score
from sklearn.model_selection import train_test_split

from src.app.transductive_mdgcn_layer import TransductiveMDGCNLayer
from src.app.supervised_mdgcn_model import SupervisedMdgcnModel

# %%
# Collecting dataframes from Elliptic datasets.
features_df = pd.read_csv("data/elliptic/elliptic_txs_features.csv", header=None)
classes_df = pd.read_csv("data/elliptic/elliptic_txs_classes.csv")
edges_df = pd.read_csv("data/elliptic/elliptic_txs_edgelist.csv")

# Collecting important features.
transaction_ids = features_df.iloc[:, 0].values # First column of features dataframe is the transaction ID.
time_steps = features_df.iloc[:, 1].values # Second column of features dataframe is the discrete time step.
node_features = features_df.iloc[:, 2:].values # The rest of 165 columns are features related to bitcoin transactions.

# %% [markdown]
# ### Build the graph

# %%
G = nx.DiGraph()

# Every transaction id is a node in my graph.
for transaction in transaction_ids:
    G.add_node(transaction)

# Every transaction operation is an edge connection between two nodes in my graph.
for _, row in edges_df.iterrows():
    G.add_edge(row["txId1"], row["txId2"])

# %%
transaction_to_index = {transaction: index for index, transaction in enumerate(transaction_ids)}

# %%
N = len(transaction_ids)

# 1. Collect only the indices of the edges (no giant zero matrix)
indices = []
for _, row in edges_df.iterrows():
    i = transaction_to_index[row["txId1"]]
    j = transaction_to_index[row["txId2"]]
    indices.append([i, j])


# 2. Define the values (all 1s in your case) and the shape
# Use float32 to match your original dtype
values = np.ones(len(indices), dtype=np.float32)
dense_shape = [N, N]

# 3. Create the SparseTensor directly
# This uses only a few MBs of RAM instead of 154 GB
adjacent_matrix = tf.sparse.SparseTensor(
    indices=indices,
    values=values,
    dense_shape=dense_shape
)

# 4. (Optional) Reorder indices if they aren't in row-major order
# Many TensorFlow sparse operations require this
adjacent_matrix = tf.sparse.reorder(adjacent_matrix)

# %%
def compute_distance_adj_sparse(G, tx_to_idx, K):

    N = len(tx_to_idx)

    # Collect sparse indices per hop
    indices_per_hop = [[] for _ in range(K + 1)]

    for tx in G.nodes():

        src = tx_to_idx[tx]

        lengths = nx.single_source_shortest_path_length(
            G, tx, cutoff=K
        )

        for tgt, d in lengths.items():
            if d <= K:
                tgt_idx = tx_to_idx[tgt]
                indices_per_hop[d].append([src, tgt_idx])

    A_dist_list = []

    for hop in range(K + 1):

        indices = indices_per_hop[hop]

        if len(indices) == 0:
            indices = np.zeros((0, 2), dtype=np.int64)

        values = np.ones(len(indices), dtype=np.float32)

        A_sparse = tf.sparse.SparseTensor(
            indices=indices,
            values=values,
            dense_shape=[N, N]
        )

        A_sparse = tf.sparse.reorder(A_sparse)

        A_dist_list.append(A_sparse)

    return A_dist_list

adjacent_dist_list = compute_distance_adj_sparse(G, transaction_to_index, K=2)

# %%
labels_df = classes_df.set_index("txId")

y = []
labels_array = []

for tx in transaction_ids:
    label = labels_df.loc[tx]["class"]

    if label == "unknown":
        y.append(0)
        labels_array.append(0)
    else:
        y.append(1 if label == "1" else 0)
        labels_array.append(1)

y = tf.constant(y, dtype=tf.float32)
# mask = tf.constant(labels_array, dtype=tf.float32)

# labels: 0 = licit, 1 = illicit
labels = tf.convert_to_tensor(labels_array, dtype=tf.float32)
labels = tf.reshape(labels, (-1, 1))   # [N, 1]

# %% [markdown]
# ### Split Data in Train, Validation and Test

# %%
indices = np.arange(N)
labels_np = labels.numpy() if isinstance(labels, tf.Tensor) else labels

# Train / temp split
train_idx, temp_idx, y_train, y_temp = train_test_split(
    indices, labels_np, stratify=labels_np, test_size=0.3, random_state=42
)

# Temp -> val / test split
val_idx, test_idx, y_val, y_test = train_test_split(
    temp_idx, labels_np[temp_idx], stratify=labels_np[temp_idx], test_size=0.5, random_state=42
)

# Convert to boolean masks
train_mask = np.zeros(N, dtype=bool)
train_mask[train_idx] = True

val_mask = np.zeros(N, dtype=bool)
val_mask[val_idx] = True

test_mask = np.zeros(N, dtype=bool)
test_mask[test_idx] = True

train_mask = tf.convert_to_tensor(train_mask)
val_mask = tf.convert_to_tensor(val_mask)
test_mask = tf.convert_to_tensor(test_mask)

# %%
print('train_mask.shape', train_mask.shape, np.sum(train_mask))
print('val_mask.shape', val_mask.shape, np.sum(val_mask))
print('test_mask.shape', val_mask.shape, np.sum(val_mask))
print('node_features.shape', node_features.shape)
# Out:
# train_mask.shape (203769,) 142638
# val_mask.shape (203769,) 30565
# test_mask.shape (203769,) 30565
# node_features.shape (203769, 165)

# %%
model = SupervisedMdgcnModel(
    num_nodes=N,
    in_dim=node_features.shape[1],
    hidden_dim=64,
    K=2
)

optimizer = tf.keras.optimizers.Adam(learning_rate=1e-3)

# %% [markdown]
# ### Evaluation Function and Validation Step

# %%
# F1 + AUC
def evaluate(model, X, A_list, y, mask):

    preds = model(X, A_list).numpy()
    preds_binary = (preds > 0.5).astype(int)

    y_true = y.numpy()[mask]
    y_pred = preds_binary[mask]
    y_prob = preds[mask]

    f1 = f1_score(y_true, y_pred)
    auc = roc_auc_score(y_true, y_prob)

    return f1, auc

# Binary Cross Entropy
def masked_bce(y_true, y_pred, mask):
    mask = tf.cast(mask, tf.float32)
    loss = tf.keras.losses.binary_crossentropy(
        y_true * mask[:, None],
        y_pred * mask[:, None]
    )
    return loss

# Instead of SMOTE (not good for graphs), use weighted BCE:
def weighted_masked_bce(y_true, y_pred, mask, class_weight = 5.0):

    weights = tf.where(y_true == 1, class_weight, 1.0)

    mask = tf.cast(mask, tf.float32)

    loss = tf.keras.losses.binary_crossentropy(y_true, y_pred)
    loss = loss * weights * mask[:, None]

    return tf.reduce_mean(loss)

# %%
@tf.function
def train_step(model, X, A_list, y, mask):

    with tf.GradientTape() as tape:
        predictions = model(X, A_list)
        loss = masked_bce(y, predictions, mask)

    gradients = tape.gradient(loss, model.trainable_variables)
    optimizer.apply_gradients(zip(gradients, model.trainable_variables))

    return loss
    
@tf.function
def val_step(model, X, A_list, y, mask):

    predictions = model(X, A_list)
    loss = masked_bce(y, predictions, mask)

    return loss, predictions

# %%
EPOCHS = 100

for epoch in range(EPOCHS):

    train_loss = train_step(
        model,
        node_features,
        adjacent_dist_list,
        labels,
        train_mask
    )

    val_loss, val_preds = val_step(
        model,
        node_features,
        adjacent_dist_list,
        labels,
        val_mask
    )

    if epoch % 10 == 0:
        print(f"Epoch {epoch}")
        print("Train Loss:", train_loss.numpy())
        print("Val Loss:", val_loss.numpy())
# Out:
# Epoch 0
# Train Loss: [5.201605e-01 6.088088e-01 1.192093e-07 ... 3.227931e-01 1.192093e-07
#  9.127956e-01]
# Val Loss: [1.1920930e-07 1.1920930e-07 1.1920930e-07 ... 1.1920930e-07 3.2899138e-01
#  1.1920929e-07]
# Epoch 10
# Train Loss: [1.1920930e-07 7.1525602e-07 1.1920930e-07 ... 3.3498374e-05 1.1920930e-07
#  1.1920929e-07]
# Val Loss: [1.1920930e-07 1.1920930e-07 1.1920930e-07 ... 1.1920930e-07 2.6131400e-01
#  1.1920929e-07]
# Epoch 20
# Train Loss: [1.1920930e-07 1.1920930e-07 1.1920930e-07 ... 1.1920930e-07 1.1920930e-07
#  1.1920929e-07]
# Val Loss: [1.1920930e-07 1.1920930e-07 1.1920930e-07 ... 1.1920930e-07 2.8209257e-01
#  1.1920929e-07]
# Epoch 30
# Train Loss: [1.1920930e-07 1.1920930e-07 1.1920930e-07 ... 1.1920930e-07 1.1920930e-07
#  1.1920929e-07]
# Val Loss: [1.1920930e-07 1.1920930e-07 1.1920930e-07 ... 1.1920930e-07 2.9425278e-01
#  1.1920929e-07]
# Epoch 40
# Train Loss: [1.1920930e-07 1.1920930e-07 1.1920930e-07 ... 1.1920930e-07 1.1920930e-07
#  1.1920929e-07]
# Val Loss: [1.1920930e-07 1.1920930e-07 1.1920930e-07 ... 1.1920930e-07 2.9999641e-01
#  1.1920929e-07]
# Epoch 50
# Train Loss: [1.1920930e-07 1.1920930e-07 1.1920930e-07 ... 1.1920930e-07 1.1920930e-07
#  1.1920929e-07]
# Val Loss: [1.1920930e-07 1.1920930e-07 1.1920930e-07 ... 1.1920930e-07 3.0278370e-01
#  1.1920929e-07]
# Epoch 60
# Train Loss: [1.1920930e-07 1.1920930e-07 1.1920930e-07 ... 1.1920930e-07 1.1920930e-07
#  1.1920929e-07]
# Val Loss: [1.1920930e-07 1.1920930e-07 1.1920930e-07 ... 1.1920930e-07 3.0391705e-01
#  1.1920929e-07]
# Epoch 70
# Train Loss: [1.1920930e-07 1.1920930e-07 1.1920930e-07 ... 1.1920930e-07 1.1920930e-07
#  1.1920929e-07]
# Val Loss: [1.1920930e-07 1.1920930e-07 1.1920930e-07 ... 1.1920930e-07 3.0435598e-01
#  1.1920929e-07]
# Epoch 80
# Train Loss: [1.1920930e-07 1.1920930e-07 1.1920930e-07 ... 1.1920930e-07 1.1920930e-07
#  1.1920929e-07]
# Val Loss: [1.1920930e-07 1.1920930e-07 1.1920930e-07 ... 1.1920930e-07 3.0452174e-01
#  1.1920929e-07]
# Epoch 90
# Train Loss: [1.1920930e-07 1.1920930e-07 1.1920930e-07 ... 1.1920930e-07 1.1920930e-07
#  1.1920929e-07]
# Val Loss: [1.1920930e-07 1.1920930e-07 1.1920930e-07 ... 1.1920930e-07 3.0458364e-01
#  1.1920929e-07]

# %% [markdown]
# ### Evaluation Metrics (Very Important for Imbalance)

# %%
# After training, evaluate
f1_val, auc_val = evaluate(model, node_features, adjacent_dist_list, labels, val_mask)
f1_test, auc_test = evaluate(model, node_features, adjacent_dist_list, labels, test_mask)

print(f"Validation F1: {f1_val:.4f}, AUC: {auc_val:.4f}")
print(f"Test F1: {f1_test:.4f}, AUC: {auc_test:.4f}")
# Out:
# Validation F1: 0.3642, AUC: 0.5904
# Test F1: 0.3701, AUC: 0.5976
